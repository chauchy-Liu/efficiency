# %%
import os
os.system("unset http_proxy")
os.system("unset https_proxy")
os.system("unset all_proxy")
os.system('echo -e "已关闭代理"')
# Out:
# -e 已关闭代理
# 0

# %% [markdown]
# # 配置测点

# %%
xny_xtjs_electricity_year = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", "onboardingType"],
    "时间": ["year_no", ""],
    "计划发电量：千瓦时": ["production_budget", "PlannedProduction", "PlannedProduction"],
    "年累计发电量：千瓦时(每日更新)": ["production", "ActiveProduction", "GDTJT2025.APProduction"],
    "发电量同期：千瓦时": ["production_lastyear", "ActiveProductionSPLY", ""],
    "发电完成率：%": ["production_rate", "PlannedCompRate", "PlannedCompRate"],
    "发电量同比增减：万千瓦时": ["production_yoy", "", ""],
    "利用小时数：h": ["full_load_hours", "GDTJT.EquivalentYield", "SITE.FullHour"],
    "上网电量：千瓦时": ["on_grid_energy", "OnGidEnergy", "OnGridEnergy"],
    "上网电量同期：千瓦时": ["on_grid_energy_lastyear", "", ""],
    "购网电量：千瓦时": ["off_grid_energy", "", ""],
    "购网电量同期：千瓦时": ["off_grid_energy_lastyear", "", ""],
    
}
xny_xtjs_electricity_day = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", "onboardingType"],
    "时间": ["day_no", ""],
    "发电量：千瓦时": ["production", "ActiveProduction", "GDTJT2025.APProduction"],
    
}
xny_xtjs_operate_day = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", "onboardingType"],
    "时间": ["day_no", ""],
    "昨日实时电价：元/千瓦时": ["realtime_price", ""],
    "日前电价(日前交易电价)：元/千瓦时": ["day_trade_price", ""]
    
}
xny_xtjs_resource_day = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["day_no", ""],
    "平均风速：m/s": ["wind_speed", "GDTJT.WENL_GENERAL"],
    "辐照度：瓦/平方米": ["radiation", "SITE.IrradianceAvg"],
    "天气": ["weather", "", "SITE.Weather"],
    
}

xny_xtjs_resource_year = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "平均风速：m/s": ["wind_speed", "GDTJT.WENL_GENERAL"],
    "年累计辐照：兆焦每平方米": ["radiation", "feasibleIrradiationAnnual"],
    
}
xny_xtjs_hse_day = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["day_no", ""],
    "违章次数：次": ["illegal_num", ""]
}
xny_xtjs_hse_year = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "节约标煤：吨": ["coal_reduction", "CoalReduction", "CoalReduction"],
    "二氧化碳减排：吨": ["co2_reduction", "CO2Reduction", "CO2Reduction"]
}

xny_xtjs_operate_month = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["month_no", ""],
    "营业利润：元": ["profit", "GTDJT.ElectricityProfit", "GTDJT.ElectricityProfit"]
}

xny_xtjs_property_year = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "装机容量：千瓦": ["capacity", "capacity"],
    "风机设备数量（机组）：台": ["turbines_num", "WENL_SITE.EQUIPMENT_AMOUNT"],
    "光伏逆变器数量：台": ["pv_inverter_num", ""],
    "场站光伏组件总面积：平方米": ["extent", ""],
}

xny_tjfx_accumulated_profit_com = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "完成率": ["completion_rate", "PlannedCompRate", "PlannedCompRate"],
}

xny_tjfx_profit_per_kilowatt_co = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "单位千瓦利润：（元/千瓦）": ["profit_per_kilowatt", "GTDJT.ElectricityProfit", "GTDJT.ElectricityProfit"],
    "发电类型：1风电/2光伏": ["power_generation_type", ""],
}
xny_tjfx_cost_per_kwh_completio = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "发电类型：1风电/2光伏": ["power_generation_type", ""],
    "度电成本（元/千千瓦时）": ["cost_per_kwh", "GTDJT.ElectricityCost", "GTDJT.ElectricityCost"],
}
xny_tjfx_utilization_hours_comp = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "发电类型：1风电/2光伏": ["power_generation_type", ""],
    "利用小时数（小时）": ["utilization_hours", "GDTJT.EquivalentYield", "SITE.FullHour"],
}
xny_tjfx_wind_energy_availabili = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "风机可利用率（%）": ["wind_energy_availability", "GDTJT.WENL_GENERAL.PBA", "GDTJT2.TBASITE"],
}
xny_tjfx_time_availability = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "发电类型：1风电/2光伏": ["power_generation_type", ""],
    "时间可利用率": ["time_availability", "GDTJT.WENL_GENERAL.TBA", ""],
}
xny_tjfx_fault_free_turbine_per = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "无故障风机台数占比": ["fault_free_turbine_ratio", ""],
}

xny_tjfx_fault_free_pv_subarray = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "无故障光伏子阵台数占比": ["fault_free_pv_subarray_ratio", "", "BXTFTroubleFreeRatioSelfRecovered	"],
}
xny_tjfx_pv_string_break_loss_p = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "时间": ["year_no", ""],
    "单位名称/场站名称": ["unit_or_station_name", ""],
    "排名": ["ranking", ""],
    "组串断路损失电量占比": ["string_break_loss_ratio", "", "GDTJT2025.SringDown"],
}
real_time_equipment_operation = {
    "关联组织id": ["org_id", ""],
    "组织路径": ["parent_ids", ""],
    "时间(三十分钟一个点)": ["show_time", ""],
    "产业类型": ["station_type", ""],
    "实时功率": ["real_time_power", ""],
    "理论功率": ["theoretical_power", ""],
    "预测功率": ["predicted_power", ""],
    "风速": ["wind_speed", ""],
    "光照度": ["illuminance", ""],
}
station_equipment = {
    "关联组织id": ["org_id", ""],
    "组织路径": ["parent_ids", ""],
    "产业类型": ["station_type", ""],
    "正常发电状态数量": ["normal_power_generation_num", ""],
    "有维护状态数量": ["under_maintenance_num", ""],
    "有故障状态数量": ["faulty_state_num", ""],
    "无连接状态数量": ["disconnected_state_num", ""],
}
radiation_equipment = {
    "关联组织id": ["org_id", ""],
    "组织路径": ["parent_ids", ""],
    "正常运行数量": ["normal_power_generation_num", ""],
    "限电运行数量": ["power_rationing_num", ""],
    "故障停运数量": ["fault_outage_state", ""],
    "未知停运数量": ["unknown_outage_state_num", ""],
    "通讯中断数量": ["communication_interruption_state_num", ""],
    "手动停运数量": ["manual_shutdown_state_num", ""],
    "环境停运数量": ["environmental_shutdown_state_num", ""],
}
wind_power_equipment = {
    "关联组织id": ["org_id", ""],
    "组织路径": ["parent_ids", ""],
    "正常发电状态数量": ["normal_power_generation_num", ""],
    "服务状态数量": ["service_status_num", ""],
    "故障停运数量": ["outage_state_num", ""],
    "限功率数量": ["power_limited_state_num", ""],
    "用户停机数量": ["user_shutdown_state_num", ""],
    "电网故障数量": ["power_grid_failure_state_num", ""],
    "环境待命数量": ["environmental_standby_state_num", ""],
    "技术待命数量": ["technical_standby_state_num", ""],
    "未知状态数量": ["unknown_outage_state_num", ""],
}
xny_org_extend = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", ""],
    "装机容量：千瓦": ["capacity", ""],
    "额定容量：千瓦": ["rated_capacity", ""],
    "机组数量": ["turbines_num", ""],
    "逆变器数量": ["pv_nverter_num", ""],
    "经度": ["longitude", ""],
    "纬度": ["dimension", ""],
    "场站光伏组件总面积": ["cover_area", ""],
    "光伏子阵数量": ["subarray_num", ""],
}

# %%
# 配置
# farmAttUrl = "https://ag-spic1.eniot.io/cds-asset-service/v1.0/attribute"
farmAttUrl = 'https://ag-spic1.eniot.io/cds-asset-service/v1.0/hierarchy?' #orgId=o16323808037221371&mdmIds=Z3Kw1DNz&mdmTypes=EnOS_Wind_Farm&attributes=&locale=zh-CN'
farmPointUrl = "https://ag-spic1.eniot.io/cds-timeseries-service/v1.0/tsdb-detail"
farmMetricUrl = "https://ag-spic1.eniot.io/cds-metric-service/v1.0/metric?"
orgId="o16323808037221371"
AccessKey = '3f207c85-64b4-476c-a23d-64624bbc0669'
SecretKey = 'f30502cc-2b51-41d0-a95b-6275d609e5bf'

#内蒙所有场站
windFarmName = ["内蒙古赤峰阿尔泰风电场", "内蒙古赤峰三道井风电场", "内蒙古锡林郭勒绿地风电场", "内蒙古通辽道老杜风电场", "内蒙古通辽珠日河风电场", "内蒙古乌兰察布贺希格风电场", "内蒙古乌兰察布青格洱风电场", "内蒙古阿拉善布拉格风电场", "内蒙古通辽霍煤鸿骏新园风电场", "内蒙古霍煤鸿骏风电场（D厂五期）", "内蒙古霍煤鸿骏风电场（D厂四期）	", "内蒙古阿拉善盟木诺日风电场", "内蒙古通辽霍煤鸿骏D厂三期风电场", "内蒙古通辽霍煤鸿骏D厂一期风电场", "内蒙古通辽霍煤鸿骏D厂二期风电场", "内蒙古锡林浩特敖伦风电场", "湖北荆门子陵铺风电场", "山西朔州甘泉山风电场", "山西吕梁交口风电场（二期）	", "山西吕梁交口风电场（一期）", "河南浚县火龙岗风电场", "内蒙古通辽后旗花灯一期风电场", "内蒙古通辽后旗花灯二期风电场", "内蒙古通辽开鲁建华一期风电场", "内蒙古通辽开鲁建华二期风电场", "内蒙古扎旗阿日昆都楞风电场（一期）	", "内蒙古扎旗阿日昆都楞风电场（二期）", "内蒙古扎旗阿日昆都楞风电场（三期）	", "内蒙古扎旗阿日昆都楞风电场（四期）", "内蒙古包头固阳保力图风电场", "内蒙古二连长风风电场"]
windAssetIds = ["4gFAmrhn", "3Sx6QZ4Z", "ImgcYP82", "Z3Kw1DNz", "L3EWAdto", "DMYrRge8", "5n1kNJeb", "aFPXpplp", "eOac1sow", "NZ7D4Gi0", "oQzjEzpf", "AcVjRFp9", "OmqhZtje", "PhMoFWGe", "5rsGLMhA", "iFKMBKxw", "3Ui6wnTn", "ioPLF6UP", "wBvTK9gr", "ONCWHV4O", "AZ6eyxCM", "0di8qdZR", "Y6vznymw", "taHGv2sw", "sxoJwg36", "GzgtzKDO", "eUH3gjT4", "RQ1mkJgr", "rxHjXCre", "yueLvGmW", "gy4eHwBw"]
solarFarmName = ["内蒙古锡林郭勒盟白音华光伏电站", "内蒙古通辽霍煤鸿骏光伏电站", "内蒙古鄂尔多斯玛瑙湖光伏电站", "霍林河露天煤业光伏电站", "内蒙古阿拉善陶力光伏电站", "内蒙古通辽通发光伏电站	", "内蒙古蒙西土右光伏电站", "内蒙古阿日昆都楞光伏电站", "内蒙古协合阿日昆都楞光伏电站", "达拉特光伏一期（水镜湖光伏电站）", "达拉特光伏一期（羽龙湖光伏电站）	", "达拉特光伏一期（天赐湖光伏电站）"]
solarAssetIds = ["iX25Lb0W", "rRa34k5x", "h0UGFJhk", "svdvQDOi", "awa8DaO6", "pYTisap6", "xKW3wWlu", "IDy6jWhd", "zjl6jrEB", "iuvHKyUL", "rh0dYWv3", "UZZ0uZ7q"]

# %% [markdown]
# # xny_xtjs_electricity_month

# %%
xny_xtjs_electricity_month = {
    "组织编码": ["org_code", ""],
    "组织名称": ["org_name", ""],
    "组织类型": ["org_type", ""],
    "场站类型": ["station_type", ""],
    "接入方式": ["access_type", "onboardingType"],
    "时间": ["month_no", ""],
    "计划发电量：千瓦时": ["production_budget", "PlannedProduction", "PlannedProduction"],
    "月累计发电量：千瓦时(每日更新)": ["production", "ActiveProduction", "GDTJT2025.APProduction"],
    "发电量同期：千瓦时": ["production_lastyear", "ActiveProductionSPLY", ""],
    "发电完成率：%": ["production_rate", "PlannedCompRate", "PlannedCompRate"],
    "发电量同比增减：万千瓦时": ["production_yoy", "", ""],
    "月发电超欠量：千瓦时": ["overdue", "", "OverDebt"],
    "利用小时数：h": ["full_load_hours", "GDTJT.EquivalentYield", "SITE.FullHour"],
    
}

#风机指标
windMetrics = ["production_budget",]
#光伏指标
solarMetrics = ["production_budget",]

# %%
from poseidon.poseidon import urlopen 
import pandas as pd
import numpy as np
# 请求函数
def farmMetricsRequest(AccessKey, SecretKey, url, params):
    farmMetircs = pd.DataFrame()
    url = url + "orgId="+orgId
    ResponsePoint = urlopen(AccessKey, SecretKey, url, params)
    
    # url = url + "action=query" + "&orgId="+orgId
    # for key, value in params.items():
    #     url = url + "&"+key+"="+value
    # ResponsePoint = urlopen(AccessKey, SecretKey, url)

    if ResponsePoint and ResponsePoint['pagination']['pageSize'] > 0:
        WindFarm = pd.DataFrame(ResponsePoint['data'])
        for i in WindFarm.shape[0]:
            if "fullName" in WindFarm['attributes'][0]:
                farmMetircs.loc[i,'风电场名'] = list(map(lambda x: x['fullName'], WindFarm['attributes']))[0]
            elif "name" in WindFarm['attributes'][0]:
                farmMetircs.loc[i,'风电场名'] = list(map(lambda x: x['name'], WindFarm['attributes']))[0]
            else:
                farmMetircs.loc[i,'风电场名'] = np.nan
            farmMetircs.loc[i,'mdmId'] = list(map(lambda x: x['mdmId'], WindFarm['attributes']))[0]
    return farmMetircs

# %%
from poseidon.poseidon import urlopen 
import pandas as pd
import numpy as np

#########风场指标数据读取
def WindFarm_metrics_Enos(AccessKey,SecretKey,assetIds,url,starttime,endtime):
    WindFarm_metrics_temp = pd.DataFrame()
    metricsIds = "ActiveProduction" #"ActiveProduction,WENL_GENERAL.ALL_LOSS,PlannedCompRate,PlannedProduction,WENL_GENERAL.WIND_SPEED_AVG,WENL_GENERAL.FullHour,WENL_GENERAL.WIND_ABANDONMENT_RATE"
    timeGroup="M"
    url_asset = str(str(url) + '&mdmIds='+str(assetIds)+'&metrics='+str(metricsIds)+'&startTime='+str(starttime)+'&endTime='+str(endtime)+'&timeGroup='+str(timeGroup))

    ResponsePoint = urlopen(AccessKey, SecretKey, url_asset)
    #print(ResponsePoint)
    if ResponsePoint['pagination']['pageSize'] > 0:
        WindFarm_metrics_temp.loc[0,'mdmId'] = ResponsePoint['data'][0]['mdmId']
        if ((('ActiveProduction') in ResponsePoint['data'][0].keys())==True):
            WindFarm_metrics_temp.loc[0,'actpw'] = ResponsePoint['data'][0]['ActiveProduction']
        if ((('WENL_GENERAL.ALL_LOSS') in ResponsePoint['data'][0].keys())==True):
            WindFarm_metrics_temp.loc[0,'allloss'] = ResponsePoint['data'][0]['WENL_GENERAL.ALL_LOSS']
        if ((('PlannedCompRate') in ResponsePoint['data'][0].keys())==True):
            WindFarm_metrics_temp.loc[0,'planrate'] = ResponsePoint['data'][0]['PlannedCompRate']
        if ((('PlannedProduction') in ResponsePoint['data'][0].keys())==True):
            WindFarm_metrics_temp.loc[0,'planpw'] = ResponsePoint['data'][0]['PlannedProduction']
        if ((('WENL_GENERAL.WIND_SPEED_AVG') in ResponsePoint['data'][0].keys())==True):
            WindFarm_metrics_temp.loc[0,'wind'] = ResponsePoint['data'][0]['WENL_GENERAL.WIND_SPEED_AVG']
        if ((('WENL_GENERAL.FullHour') in ResponsePoint['data'][0].keys())==True):
            WindFarm_metrics_temp.loc[0,'hour'] = ResponsePoint['data'][0]['WENL_GENERAL.FullHour']
        if ((('WENL_GENERAL.WIND_ABANDONMENT_RATE') in ResponsePoint['data'][0].keys())==True):
            WindFarm_metrics_temp.loc[0,'abandrate'] = ResponsePoint['data'][0]['WENL_GENERAL.WIND_ABANDONMENT_RATE']
        if ((('WENL_GENERAL.WIND_ABANDONMENT_POWER') in ResponsePoint['data'][0].keys())==True):
            WindFarm_metrics_temp.loc[0,'abandpw'] = ResponsePoint['data'][0]['WENL_GENERAL.WIND_ABANDONMENT_POWER']
    return WindFarm_metrics_temp



starttime = "2025-02-01%2000:00:00"
endtime = "2025-08-01%2000:00:00"
Input_url_metric = 'https://ag-spic1.eniot.io/cds-metric-service/v1.0/metric?orgId=o16323808037221371' 

WindFarm_metrics_all = pd.DataFrame()  
for i in range(len(windAssetIds)):
    assetIds = windAssetIds[i]      
    WindFarm_metrics_temp = WindFarm_metrics_Enos(AccessKey,SecretKey,assetIds,Input_url_metric,starttime,endtime)
    # WindFarm_metrics_temp.loc[0,'name'] = WindFarm_all.loc[i,'name']
    # WindFarm_metrics_temp.loc[0,'company'] = WindFarm_all.loc[i,'company']
    # WindFarm_metrics_temp.loc[0,'province'] = WindFarm_all.loc[i,'province']
    # WindFarm_metrics_all = WindFarm_metrics_all.append(WindFarm_metrics_temp)
    print(i)
# Out:
# <urlopen error [Errno 54] Connection reset by peer>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 43
#      41 for i in range(len(windAssetIds)):
#      42     assetIds = windAssetIds[i]
# ---> 43     WindFarm_metrics_temp = WindFarm_metrics_Enos(AccessKey,SecretKey,assetIds,Input_url_metric,starttime,endtime)
#      44     # WindFarm_metrics_temp.loc[0,'name'] = WindFarm_all.loc[i,'name']
#      45     # WindFarm_metrics_temp.loc[0,'company'] = WindFarm_all.loc[i,'company']
#      46     # WindFarm_metrics_temp.loc[0,'province'] = WindFarm_all.loc[i,'province']
#      47     # WindFarm_metrics_all = WindFarm_metrics_all.append(WindFarm_metrics_temp)
#      48     print(i)
#
# Cell In[12], line 14, in WindFarm_metrics_Enos(AccessKey, SecretKey, assetIds, url, starttime, endtime)
#      12 ResponsePoint = urlopen(AccessKey, SecretKey, url_asset)
# ...

# %%
windMetrics = ["PlannedProduction"] #, "ActiveProduction", "ActiveProductionSPLY", "PlannedCompRate", "EquivalentYield"
solarPoints = []

windParamsTime1 = {
    # "Access Key": AccessKey,
    # "Secret Key": SecretKey,
    "mdmIds": None,
    "metrics": ','.join(windMetrics),
    "startTime": "2025-02-01 00:00:00",
    "endTime": "2025-09-01 00:00:00",
    "timeGroup": "M",
    "pageSize": "20000",
    "mdmTypes": "EnOS_Wind_Farm"
}
windParamsTime2 = {
    "mdmIds": None,
    "metrics": ','.join(windMetrics),
    "startTime": "2024-02-01 00:00:00",
    "endTime": "2024-09-01 00:00:00",
    "timeGroup": "M",
    "pageSize": "20000",
    "mdmTypes": "EnOS_Wind_Farm"
}
solarParamsTime1 = {
    "mdmIds": None,
    "metrics": ','.join(solarPoints),
    "startTime": "2025-02-01 00:00:00",
    "endTime": "2025-09-01 00:00:00",
    "timeGroup": "M",
    "pageSize": "20000",
    "mdmTypes": "EnOS_Solar_Site"
}
solarParamsTime2 = {
    "mdmIds": None,
    "metrics": ','.join(solarPoints),
    "startTime": "2024-02-01 00:00:00",
    "endTime": "2024-09-01 00:00:00",
    "timeGroup": "M",
    "pageSize": "20000",
    "mdmTypes": "EnOS_Solar_Site"
}
# windMetrics = []
allWindMetrics = pd.DataFrame()
allSolarMetrics = pd.DataFrame()
# for assetId in windAssetIds:
windParamsTime1["mdmIds"] = windAssetIds[3]
windMetrics = farmMetricsRequest(AccessKey, SecretKey, farmMetricUrl, windParamsTime1)
    # windMetrics.loc[:, "station_type"] =
# Out:
# <urlopen error [Errno 54] Connection reset by peer>

# %% [markdown]
# # xny_org_extend表

# %%
from poseidon.poseidon import urlopen 
import pandas as pd
import numpy as np
# 请求函数
def farmAttributeRequest(AccessKey, SecretKey, url, params):
    farmMetircs = pd.DataFrame()
    # url = url + "orgId="+orgId
    # ResponsePoint = urlopen(AccessKey, SecretKey, url, params)
    
    url = url + "&orgId="+orgId
    for key, value in params.items():
        url = url + "&"+key+"="+value
    ResponsePoint = urlopen(AccessKey, SecretKey, url)

    if ResponsePoint and ResponsePoint['pagination']['pageSize'] > 0:
        WindFarm = pd.DataFrame(ResponsePoint['data'])
        for i in WindFarm.shape[0]:
            if "fullName" in WindFarm['attributes'][0]:
                farmMetircs.loc[i,'风电场名'] = list(map(lambda x: x['fullName'], WindFarm['attributes']))[0]
            elif "name" in WindFarm['attributes'][0]:
                farmMetircs.loc[i,'风电场名'] = list(map(lambda x: x['name'], WindFarm['attributes']))[0]
            else:
                farmMetircs.loc[i,'风电场名'] = np.nan
            farmMetircs.loc[i,'mdmId'] = list(map(lambda x: x['mdmId'], WindFarm['attributes']))[0]
    return farmMetircs

# %%
windParams = {
    "mdmIds": None,
    "attributes": "",#','.join(windMetrics),
    # "startTime": "2024-02-01 00:00:00",
    # "endTime": "2024-09-01 00:00:00",
    # "timeGroup": "M",
    # "pageSize": "20000",
    "locale": "zh-CN",
    "mdmTypes": "EnOS_Wind_Farm"
}
solarParams = {
    "mdmIds": None,
    "attributes": "",#','.join(windMetrics),
    # "startTime": "2024-02-01 00:00:00",
    # "endTime": "2024-09-01 00:00:00",
    # "timeGroup": "M",
    # "pageSize": "20000",
    "locale": "zh-CN",
    "mdmTypes": "EnOS_Solar_Site"
}
allWindMetrics = pd.DataFrame()
allSolarMetrics = pd.DataFrame()
# for assetId in windAssetIds:
windParams["mdmIds"] = windAssetIds[3]
windMetrics = farmAttributeRequest(AccessKey, SecretKey, farmAttUrl, windParams)
# Out:
# <urlopen error [Errno 54] Connection reset by peer>
